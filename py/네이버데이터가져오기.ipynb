# %%
import requests

# %%
help(requests.get)
# Out:
# Help on function get in module requests.api:
#
# get(url, params=None, **kwargs)
#     Sends a GET request.
#
#     :param url: URL for the new :class:`Request` object.
#     :param params: (optional) Dictionary, list of tuples or bytes to send
#         in the query string for the :class:`Request`.
#     :param \*\*kwargs: Optional arguments that ``request`` takes.
#     :return: :class:`Response <Response>` object
#     :rtype: requests.Response

# %%
url="https://www.naver.com/"

# %%
type(url)
# Out:
# str

# %%
requests.get(url)
# Out:
# <Response [200]>

# %%
status=requests.get(url)

# %%
status.headers
# Out:
# {'Server': 'NWS', 'Date': 'Wed, 06 Sep 2023 06:14:52 GMT', 'Content-Type': 'text/html; charset=UTF-8', 'Transfer-Encoding': 'chunked', 'Connection': 'keep-alive', 'Set-Cookie': 'PM_CK_loc=158fbacd30d5824a7807e4aa5e2424b2afaf6311b8372de9d999d1f50e69fabd; Expires=Thu, 07 Sep 2023 06:14:52 GMT; Path=/; HttpOnly', 'Cache-Control': 'no-cache, no-store, must-revalidate', 'Pragma': 'no-cache', 'P3P': 'CP="CAO DSP CURa ADMa TAIa PSAa OUR LAW STP PHY ONL UNI PUR FIN COM NAV INT DEM STA PRE"', 'X-Frame-Options': 'DENY', 'X-XSS-Protection': '1; mode=block', 'Content-Encoding': 'gzip', 'Strict-Transport-Security': 'max-age=63072000; includeSubdomains', 'Referrer-Policy': 'unsafe-url'}

# %%
status.text
# Out:
# '   <!doctype html> <html lang="ko" class="fzoom"> <head> <meta charset="utf-8"> <meta name="Referrer" content="origin"> <meta http-equiv="X-UA-Compatible" content="IE=edge"> <meta name="viewport" content="width=1190"> <title>NAVER</title> <meta name="apple-mobile-web-app-title" content="NAVER"/> <meta name="robots" content="index,nofollow"/> <meta name="description" content="네이버 메인에서 다양한 정보와 유용한 컨텐츠를 만나 보세요"/> <meta property="og:title" content="네이버"> <meta property="og:url" content="https://www.naver.com/"> <meta property="og:image" content="https://s.pstatic.net/static/www/mobile/edit/2016/0705/mobile_212852414260.png"> <meta property="og:description" content="네이버 메인에서 다양한 정보와 유용한 컨텐츠를 만나 보세요"/> <meta name="twitter:card" content="summary"> <meta name="twitter:title" content=""> <meta name="twitter:url" content="https://www.naver.com/"> <meta name="twitter:image" content="https://s.pstatic.net/static/www/mobile/edit/2016/0705/mobile_212852414260.png"> <meta name="twitter:description" content="네이버 메인에서 다양한 정보와 유용한 컨텐츠를 만나 보세요"/> <link rel="shortcut icon" type="image/x-icon" href="/favicon.ico?1"> <link rel="apple-touch-icon-precomposed" href="https://s.pstatic.net/static/www/nFavicon96.png"/> <link rel="apple-touch-icon" sizes="114x114" href="https://s.pstatic.net/static/www/u/2014/0328/mma_204243574.png"/> <link rel="apple-touch-icon" href="https://s.pstatic.net/static/www/u/2014/0328/mma_20432863.png"/> <link rel="stylesheet" href="https://ssl.pstatic.net/sstatic/search/pc/css/sp_autocomplete_220526.css"> <script>window.gladsdk=window.gladsdk||{},window.gladsdk.cmd=window.gladsdk.cmd||[],window.ndpsdk=window.ndpsdk||{},window.ndpsdk.cmd=window.ndpsdk.cmd||[],window.ndpsdk.polyfill=window.ndpsdk.polyfill||{cmd:[]};var g_ssc="navertop.v5";window.nsc=g_ssc</script> <script async src="https://ssl.pstatic.net/tveta/libs/ndpsdk/prod/ndp-loader.js"></script> <script async src="https://ssl.pstatic.net/tveta/libs/glad/prod/gfp-core.js"></script> <script src="https://ssl.pstatic.net/tveta/libs/assets/js/pc/main/min/pc.veta.core.min.js" defer="defer"></script>  <script>\nwindow["EAGER-DATA"] = window["EAGER-DATA"] || {};\nwindow["EAGER-DATA"]["PC-FEED-WRAPPER"] = {"@type":"BLOCK","blocks":[{"@type":"BLOCK","blocks":[{"@type":"BLOCK","blocks":null,"materials":[{"@type":"MATERIAL-PC-FEED","title":"티셔츠 하나에 80만원? 수지가 선택한 레터링 티셔츠!","url":"https://in.naver.com/fashioncrew/topic/600302100779616","image":{"url":"https://s.pstatic.net/dthumb.phinf/?src=%22https%3A%2F%2Finfluencer-phinf.pstatic.net%2FMjAyMzA4MjRfMjAw%2FMDAxNjkyODQzNjg1NTA0.CaDyaCoIBpOVP63Ahnvy5vPBW_NID0OFKUCkUxmys4wg.mQ1_WCebo6fojq3irkHkjORWmL__yKsOhp7B-TTaFaIg.PNG%2F879d.png%22&type=ff364_236&service=navermain"},"source":{"name":"용구이","image":{"url":"https://s.pstatic.net/dthumb.phinf/?src=%22https%3A%2F%2Fhomebuilder-phinf.pstatic.net%2FMjAyMzA3MDFfMjg3%2FMDAxNjg4MjA0NTkwMjE0.62b5q-zeeiDrix7njek9x_-UtJE8z-21b1LALhhx4Ncg.BSrZnMB1jTTqstM2Q9Y5j7Jq1zyJywct4igMFXidulAg.JPEG%2F1688204590116_D9C95FB3-1FC3-4127-A835-7C2F55D00751.jpeg%22&type=nf40_40&service=navermain"}},"_id":"6441ca92c499cc07f334c608"},{"@type":"MATERIAL-PC-FEED","title":"시계 하나 사야되는데 뭘 살지 고민된다면?","url":"https://in.naver.com/thoongthoongbo/topic/603182740554336","image":{"url":"https://s.pstatic.net/dthumb.phinf/?src=%22https%3A%2F%2Finfluencer-phinf.pstatic.net%2FMjAyMzA5MDFfMjE0%2FMDAxNjkzNTYxNzg5MTkz.Li5UlCOM75i5IgaHkg06zIL9goAxo7Gp2_W9xq1THp8g.GKxdoNMjeP6JX6mfM88R91P-eDUsteAoxp1Ms5ad5p8g.PNG%2F4b22.png%22&type=ff364_236&service=navermain"},"source":{"name":"뚱뚱보의기록","image":{"url":"https://s.pstatic.net/dthumb.phinf/?src=%22https%3A%2F%2Finfluencer-phinf.pstatic.net%2FMjAyMDA1MTlfMTQ5%2FMDAxNTg5ODUwMTUwMDU3.wv0DfQKYWd5iM7XspJr7O15UPWEOwSUiHqqV5Krr8nIg.iQ8SRWdpOcOWyl4-NYdQif4wSjxmNsWEAf4bELCPSH8g.PNG%2F123.png%22&type=nf40_40&service=navermain"}},"_id":"6441ca92c499cc07f334c609"},{"@type":"MATERIAL-PC-FEED","title":"억소리가 절로 나오는 카리나 미국 패션 알아봐요","url":"https://in.naver.com/chul/topic/604090756301440","image":{"url":"h ...

# %%
#  html 분석기 BeautifulSoup

# %%
from bs4 import BeautifulSoup

# %%
bs=BeautifulSoup(status.text, "lxml")

# %%
bs.title
# Out:
# <title>NAVER</title>

# %%
bs.title.text
# Out:
# 'NAVER'

# %%
bs.find_all()

# %%
bs.find('meta')
# Out:
# <meta charset="utf-8"/>

# %%
bs.find_all('meta')
# Out:
# [<meta charset="utf-8"/>,
#  <meta content="origin" name="Referrer"/>,
#  <meta content="IE=edge" http-equiv="X-UA-Compatible"/>,
#  <meta content="width=1190" name="viewport"/>,
#  <meta content="NAVER" name="apple-mobile-web-app-title"/>,
#  <meta content="index,nofollow" name="robots"/>,
#  <meta content="네이버 메인에서 다양한 정보와 유용한 컨텐츠를 만나 보세요" name="description"/>,
#  <meta content="네이버" property="og:title"/>,
#  <meta content="https://www.naver.com/" property="og:url"/>,
#  <meta content="https://s.pstatic.net/static/www/mobile/edit/2016/0705/mobile_212852414260.png" property="og:image"/>,
#  <meta content="네이버 메인에서 다양한 정보와 유용한 컨텐츠를 만나 보세요" property="og:description"/>,
#  <meta content="summary" name="twitter:card"/>,
#  <meta content="" name="twitter:title"/>,
#  <meta content="https://www.naver.com/" name="twitter:url"/>,
#  <meta content="https://s.pstatic.net/static/www/mobile/edit/2016/0705/mobile_212852414260.png" name="twitter:image"/>,
#  <meta content="네이버 메인에서 다양한 정보와 유용한 컨텐츠를 만나 보세요" name="twitter:description"/>]

# %%
bs.find_all('meta')[6]
# Out:
# <meta content="네이버 메인에서 다양한 정보와 유용한 컨텐츠를 만나 보세요" name="description"/>
